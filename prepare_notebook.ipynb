# %% [markdown]
# # NLP Data Preparation Exercises

# %% [markdown]
# ****

# %% [markdown]
# ### 1. Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# - Lowercase everything
# - Normalize unicode characters
# - Replace anything that is not a letter, number, whitespace or a single quote.

# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd

import acquire

# %%
df = acquire.get_news_articles(cached=True)
df.head()
# Out:
#       topic                                              title  \
# 0  business  Moderna's early data shows its COVID-19 vaccin...
# 1  business  15 countries sign world's biggest free-trade p...
# 2  business  How does Moderna's COVID-19 vaccine candidate ...
# 3  business  Reliance Retail buys 96% stake in Urban Ladder...
# 4  business  Reduce foreign funding to 26% by Oct 15, 2021:...
#
#               author                                            content
# 0     Pragya Swastik  American biotechnology company Moderna on Mond...
# 1     Pragya Swastik  Fifteen Asia-Pacific countries signed the Regi...
# 2     Pragya Swastik  Moderna's initial results of late-stage trial ...
# 3  Rishabh Bhatnagar  Reliance Industries' retail arm Reliance Retai...
# 4     Pragya Swastik  The I&B Ministry on Monday asked digital media...

# %%
def basic_clean(string):
    '''
    This function takes in a string and
    returns the string normalized.
    '''
    string = unicodedata.normalize('NFKC', string)\
             .encode('ascii', 'ignore')\
             .decode('utf-8', 'ignore')
    string = re.sub(r'[^\w\s]', '', string).lower()
    return string

# %%
articles = df.content
article = articles[0]

# %%
basic_clean(article)
# Out:
# 'american biotechnology company moderna on monday announced its experimental vaccine was 945 effective in preventing covid19 based on interim data from a latestage clinical trial modernas interim analysis was based on 95 infections among trial participants who received either a placebo or the vaccine among those only five infections occurred in those who received the vaccine'

# %% [markdown]
# ### 2. Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string):
    nltk.tokenize.ToktokTokenizer(string)

# %%
def tokenize(string):
    '''
    This function takes in a string and
    returns a tokenized string.
    '''
    # Create tokenizer.
    tokenizer = nltk.tokenize.ToktokTokenizer()
    
    # Use tokenizer
    string = tokenizer.tokenize(string, return_str=True)
    
    return string

# %%
tokenize(article)
# Out:
# "American biotechnology company Moderna on Monday announced its experimental vaccine was 94.5 % effective in preventing COVID-19 based on interim data from a late-stage clinical trial. Moderna ' s interim analysis was based on 95 infections among trial participants who received either a placebo or the vaccine. Among those , only five infections occurred in those who received the vaccine ."

# %% [markdown]
# ### 3. Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    '''
    This function takes in a string and
    returns a string with words stemmed.
    '''
    # Create porter stemmer.
    ps = nltk.porter.PorterStemmer()
    
    # Use the stemmer to stem each word in the list of words we created by using split.
    stems = [ps.stem(word) for word in string.split()]
    
    # Join our lists of words into a string again and assign to a variable.
    string = ' '.join(stems)
    
    return string

# %%
stem(article)
# Out:
# "american biotechnolog compani moderna on monday announc it experiment vaccin wa 94.5% effect in prevent covid-19 base on interim data from a late-stag clinic trial. moderna' interim analysi wa base on 95 infect among trial particip who receiv either a placebo or the vaccine. among those, onli five infect occur in those who receiv the vaccine."

# %% [markdown]
# ### 4. Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(string):
    '''
    This function takes in string for and
    returns a string with words lemmatized.
    '''
    # Create the lemmatizer.
    wnl = nltk.stem.WordNetLemmatizer()
    
    # Use the lemmatizer on each word in the list of words we created by using split.
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    
    # Join our list of words into a string again and assign to a variable.
    string = ' '.join(lemmas)
    
    return string

# %%
lemmatize(article)
# Out:
# "American biotechnology company Moderna on Monday announced it experimental vaccine wa 94.5% effective in preventing COVID-19 based on interim data from a late-stage clinical trial. Moderna's interim analysis wa based on 95 infection among trial participant who received either a placebo or the vaccine. Among those, only five infection occurred in those who received the vaccine."

# %% [markdown]
# ### 5. Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
#
# - This function should define two optional parameters, extra_words and exclude_words.
# - These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
def remove_stopwords(string, extra_words=[], exclude_words=[]):
    '''
    This function takes in a string, optional extra_words and exclude_words parameters
    with default empty lists and returns a string.
    '''
    # Create stopword_list.
    stopword_list = stopwords.words('english')
    
    # Remove 'exclude_words' from stopword_list to keep these in my text.
    stopword_list = set(stopword_list) - set(exclude_words)

    # Add in 'extra_words' to stopword_list.
    stopword_list = stopword_list.union(set(extra_words))
    
    # Split words in string.
    words = string.split()
    
    # Create a list of words from my string with stopwords removed and assign to variable.
    filtered_words = [word for word in words if word not in stopword_list]
    
    # Join words in the list back into strings and assign to a variable.
    string_without_stopwords = ' '.join(filtered_words)
    
    return string_without_stopwords

# %%
remove_stopwords(article)
# Out:
# "American biotechnology company Moderna Monday announced experimental vaccine 94.5% effective preventing COVID-19 based interim data late-stage clinical trial. Moderna's interim analysis based 95 infections among trial participants received either placebo vaccine. Among those, five infections occurred received vaccine."

# %% [markdown]
# ### 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
news_df = acquire.get_news_articles(cached=False)

# %%
def prep_article_data(df, column, extra_words=[], exclude_words=[]):
    '''
    This function take in a df and the string name for a text column with 
    option to pass lists for extra_words and exclude_words and
    returns a df with the text article title, original text, stemmed text,
    lemmatized text, cleaned, tokenized, & lemmatized text with stopwords removed.
    '''
    df['clean'] = df[column].apply(basic_clean)\
                            .apply(tokenize)\
                            .apply(remove_stopwords, 
                                   extra_words=extra_words, 
                                   exclude_words=exclude_words)\
                            .apply(lemmatize)
    
    df['stemmed'] = df[column].apply(basic_clean).apply(stem)
    
    df['lemmatized'] = df[column].apply(basic_clean).apply(lemmatize)
    
    return df[['title', column, 'stemmed', 'lemmatized', 'clean']]

# %%
news_df = prep_article_data(news_df, 'content')
news_df
# Out:
#                                                 title  \
# 0   Lakshmi Vilas Bank withdrawals capped at ₹25,0...
# 1   Shutting Delhi markets may prove counterproduc...
# 2   Pfizer shares drop 4.5% as Moderna says its va...
# 3   Musk gets $15bn richer in 2 hours, becomes wor...
# 4   What have I done to deserve this: Tharoor resp...
# ..                                                ...
# 94  Aditya to start shooting for upcoming action f...
# 95  Wonder if people will take the risk: Dilijt on...
# 96  It's not easy for big stars to do OTT, but the...
# 97  My husband didn't pressure me to lose weight p...
# 98  Aditya made me feel comfortable on the sets of...
#
#                                               content  \
# 0   The Centre has imposed a 30-day moratorium on ...
# 1   Traders' body CAIT on Tuesday said a proposal ...
# 2   Pfizer’s shares fell as much as 4.5% on Monday...
# 3   Billionaire Elon Musk added $15 billion to his...
# 4   Responding to a joke on him by RPG Group's bil...
# ..                                                ...
# 94  Actor Aditya Roy Kapur will start shooting for...
# 95  Commenting on the theatrical release of his fi...
# 96  Actress Aahana S Kumra, who has featured in we...
# 97  Actress Neha Dhupia said that her husband, Ang...
# 98  Speaking about her experience of working with ...
#
#                                               stemmed  \
# 0   the centr ha impos a 30day moratorium on laksh...
# 1   trader bodi cait on tuesday said a propos to i...
# 2   pfizer share fell as much as 45 on monday afte...
# 3   billionair elon musk ad 15 billion to hi wealt...
# 4   respond to a joke on him by rpg group billiona...
# ..                                                ...
# 94  actor aditya roy kapur will start shoot for hi...
# 95  comment on the theatric releas of hi film sura...
# 96  actress aahana s kumra who ha featur in web se...
# 97  actress neha dhupia said that her husband anga...
# 98  speak about her experi of work with aditya roy...
#
#                                            lemmatized  \
# 0   the centre ha imposed a 30day moratorium on la...
# 1   trader body cait on tuesday said a proposal to...
# 2   pfizers share fell a much a 45 on monday after...
# 3   billionaire elon musk added 15 billion to his ...
# 4   responding to a joke on him by rpg group billi...
# ..                                                ...
# 94  actor aditya roy kapur will start shooting for...
# 95  commenting on the theatrical release of his fi...
# 96  actress aahana s kumra who ha featured in web ...
# 97  actress neha dhupia said that her husband anga...
# 98  speaking about her experience of working with ...
#
#                                                 clean
# 0   centre imposed 30day moratorium lakshmi vila b...
# 1   trader body cait tuesday said proposal impose ...
# 2   pfizers share fell much 45 monday rival modern...
# 3   billionaire elon musk added 15 billion wealth ...
# 4   responding joke rpg group billionaire chairman...
# ..                                                ...
# 94  actor aditya roy kapur start shooting upcoming...
# 95  commenting theatrical release film suraj pe ma...
# 96  actress aahana kumra featured web series insid...
# 97  actress neha dhupia said husband angad bedi ne...
# 98  speaking experience working aditya roy kapur l...
#
# [99 rows x 5 columns]

# %% [markdown]
# ### 7. Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
urls = acquire.get_all_urls()
codeup_df = acquire.get_blog_articles(urls=urls, cached = True)
codeup_df.head()
# Out:
#                                          title  \
# 0                    What is Machine Learning?
# 1      Introducing Our Salary Refund Guarantee
# 2                     Codeup Launches Houston!
# 3            Codeup Grads Win CivTech Datathon
# 4  How Codeup Alumni are Helping to Make Water
#
#                                              content
# 0  There’s a lot we can learn about machines, and...
# 1  Here at Codeup, we believe it’s time to revolu...
# 2  Houston, we have a problem: there aren’t enoug...
# 3  Many Codeup alumni enjoy competing in hackatho...
# 4  Imagine having a kit mailed to you with all th...

# %%
prep_article_data(codeup_df, 'content')
# Out:
#                                                 title  \
# 0                           What is Machine Learning?
# 1             Introducing Our Salary Refund Guarantee
# 2                            Codeup Launches Houston!
# 3                   Codeup Grads Win CivTech Datathon
# 4         How Codeup Alumni are Helping to Make Water
# 5      What is the Transition into Data Science Like?
# 6                What Data Science Career is For You?
# 7                            What to Expect at Codeup
# 8                                     What is Python?
# 9                     Your Education is an Investment
# 10  How Codeup Alumni Helped Dallas Youth Fight CO...
# 11  Codeup on Inc. 5000 Fastest Growing Private Co...
# 12  From Slacker to Data Scientist: Journey to Dat...
# 13                How to Succeed in a Coding Bootcamp
# 14              What is Codeup’s Application Process?
# 15  Announcing: The Annie Easley Scholarship to Su...
# 16     Build Your Career in Tech: Advice from Alumni!
# 17  What are the Math and Stats Principles You Nee...
# 18  How We’re Celebrating World Mental Health Day ...
# 19    Alumni Share their Journey into Web Development
#
#                                               content  \
# 0   There’s a lot we can learn about machines, and...
# 1   Here at Codeup, we believe it’s time to revolu...
# 2   Houston, we have a problem: there aren’t enoug...
# 3   Many Codeup alumni enjoy competing in hackatho...
# 4   Imagine having a kit mailed to you with all th...
# 5   Alumni Katy Salts and Brandi Reger joined us a...
# 6   If you’re struggling to see yourself as a data...
# 7   Setting Expectations for Life Before, During, ...
# 8   If you’ve been digging around our website or r...
# 9   You have many options regarding educational ro...
# 10  Three of our Web Development alumni from Dalla...
# 11  We’re excited to announce a huge Codeup achiev...
# 12  Butterflies in my belly; my stomach is tied up...
# 13  We held a virtual event called “How to Succeed...
# 14  Curious about Codeup’s application process? Wo...
# 15  We have an exciting announcement! We’re launch...
# 16  Bryan Walsh, Codeup Web Development alum, and ...
# 17  Coming into our Data Science program, you will...
# 18  World Mental Health Day is on October 10th. Al...
# 19  Everyone starts somewhere. Many developers out...
#
#                                               stemmed  \
# 0   there a lot we can learn about machin and ther...
# 1   here at codeup we believ it time to revolution...
# 2   houston we have a problem there arent enough s...
# 3   mani codeup alumni enjoy compet in hackathon a...
# 4   imagin have a kit mail to you with all the nec...
# 5   alumni kati salt and brandi reger join us at a...
# 6   if your struggl to see yourself as a data scie...
# 7   set expect for life befor dure and after codeu...
# 8   if youv been dig around our websit or research...
# 9   you have mani option regard educ rout to your ...
# 10  three of our web develop alumni from dalla rex...
# 11  were excit to announc a huge codeup achiev inc...
# 12  butterfli in my belli my stomach is tie up in ...
# 13  we held a virtual event call how to succeed in...
# 14  curiou about codeup applic process wonder whi ...
# 15  we have an excit announc were launch a new sch...
# 16  bryan walsh codeup web develop alum and misti ...
# 17  come into our data scienc program you will nee...
# 18  world mental health day is on octob 10th all o...
# 19  everyon start somewher mani develop out there ...
#
#                                            lemmatized  \
# 0   there a lot we can learn about machine and the...
# 1   here at codeup we believe it time to revolutio...
# 2   houston we have a problem there arent enough s...
# 3   many codeup alumnus enjoy competing in hackath...
# 4   imagine having a kit mailed to you with all th...
# 5   alumnus katy salt and brandi reger joined u at...
# 6   if youre struggling to see yourself a a data s...
# 7   setting expectation for life before during and...
# 8   if youve been digging around our website or re...
# 9   you have many option regarding educational rou...
# 10  three of our web development alumnus from dall...
# 11  were excited to announce a huge codeup achieve...
# 12  butterfly in my belly my stomach is tied up in...
# 13  we held a virtual event called how to succeed ...
# 14  curious about codeups application process wond...
# 15  we have an exciting announcement were launchin...
# 16  bryan walsh codeup web development alum and mi...
# 17  coming into our data science program you will ...
# 18  world mental health day is on october 10th all...
# 19  everyone start somewhere many developer out th...
#
#                                                 clean
# 0   there lot learn machine there lot machine lear...
# 1   codeup believe time revolutionize hiring launc...
# 2   houston problem arent enough software develope...
# 3   many codeup alumnus enjoy competing hackathons...
# 4   imagine kit mailed necessary component make co...
# 5   alumnus katy salt brandi reger joined u public...
# 6   youre struggling see data science professional...
# 7   setting expectation life codeup wondering whet...
# 8   youve digging around website researching tech ...
# 9   many option regarding educational route desire...
# 10  three web development alumnus dallas rex sutto...
# 11  excited announce huge codeup achievement inc m...
# 12  butterfly belly stomach tied knot know im taki...
# 13  held virtual event called succeed coding bootc...
# 14  curious codeups application process wondering ...
# 15  exciting announcement launching new scholarshi...
# 16  bryan walsh codeup web development alum misty ...
# 17  coming data science program need know math sta...
# 18  world mental health day october 10th u codeup ...
# 19  everyone start somewhere many developer didnt ...

# %% [markdown]
# ### 8. For each dataframe, produce the following columns:
#
# - title to hold the title
# - original to hold the original article/post content
# - clean to hold the normalized and tokenized original with the stopwords removed.
# - stemmed to hold the stemmed version of the cleaned data.
# - lemmatized to hold the lemmatized version of the cleaned data.

# %%
# completed above

# %% [markdown]
# ### 9. Ask yourself:
#
# - A. If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
#     - **lemmatize**
# - B. If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
#     - **either**
# - C. If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?
#     - **stemmed**
